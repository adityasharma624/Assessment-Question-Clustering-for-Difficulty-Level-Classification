# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../datasets/leetcode_full_metadata.csv')

# %%
df.head()
# Out:
#                                                title  \
# 0                     Convert Number Words to Digits
# 1                         Evaluate Valid Expressions
# 2  Concatenate Non-Zero Digits and Multiply by Su...
# 3  Concatenate Non-Zero Digits and Multiply by Sum I
# 4                   Number of Effective Subsequences
#
#                                                 slug  frontendQuestionId  \
# 0                     convert-number-words-to-digits                4148
# 1                         evaluate-valid-expressions                4140
# 2  concatenate-non-zero-digits-and-multiply-by-su...                4136
# 3  concatenate-non-zero-digits-and-multiply-by-sum-i                4135
# 4                   number-of-effective-subsequences                4134
#
#    acRate    difficulty  paidOnly_basic  isFavor  status  likes  dislikes  \
# 0     NaN  {'level': 2}            True    False     NaN      3         1
# ...
